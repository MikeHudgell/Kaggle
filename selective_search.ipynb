# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import scipy
import skimage.data
import selectivesearch
import matplotlib.patches as mpatches

img_path = '/home/ubuntu/data/fish/valid/LAG/img_04734.jpg'
img = mpimg.imread(img_path)
plt.imshow(img) #(scipy.misc.imresize(img, (2048,4096), interp='nearest'))
plt.show()

# %%
img_lbl, regions = selectivesearch.selective_search(img, scale=500, sigma=0.9, min_size=10)
regions[:10]
# Out:
# [{'labels': [0.0], 'rect': (0, 0, 451, 15), 'size': 3404},
#  {'labels': [1.0], 'rect': (129, 0, 322, 15), 'size': 340},
#  {'labels': [2.0], 'rect': (451, 0, 1, 16), 'size': 18},
#  {'labels': [3.0], 'rect': (68, 0, 456, 122), 'size': 31869},
#  {'labels': [4.0], 'rect': (482, 0, 44, 62), 'size': 215},
#  {'labels': [5.0], 'rect': (484, 0, 212, 90), 'size': 15382},
#  {'labels': [6.0], 'rect': (648, 0, 57, 86), 'size': 826},
#  {'labels': [7.0], 'rect': (702, 0, 477, 444), 'size': 86939},
#  {'labels': [8.0], 'rect': (781, 0, 3, 4), 'size': 18},
#  {'labels': [9.0], 'rect': (788, 0, 54, 5), 'size': 217}]

# %%
candidates = set()
for r in regions:
    # excluding same rectangle (with different segments)
    if r['rect'] in candidates:
        continue
    # excluding regions smaller than 2000 pixels
    if r['size'] < 2000:
        continue
        # distorted rects
    x, y, w, h = r['rect']
    if w / h > 1.2 or h / w > 1.2:
        continue
    candidates.add(r['rect'])

# %%
candidates
# Out:
# {(0, 0, 1279, 719),
#  (0, 17, 248, 222),
#  (0, 69, 1279, 650),
#  (0, 70, 1279, 649),
#  (0, 547, 158, 101),
#  (133, 589, 115, 67),
#  (242, 475, 235, 124),
#  (323, 475, 154, 124),
#  (393, 444, 90, 108),
#  (393, 444, 90, 136),
#  (393, 444, 90, 165),
#  (404, 579, 157, 95),
#  (484, 0, 795, 576),
#  (551, 0, 706, 448),
#  (551, 0, 706, 517),
#  (551, 0, 710, 517),
#  (551, 0, 728, 517),
#  (551, 0, 728, 576),
#  (551, 65, 154, 145),
#  (565, 382, 150, 194),
#  (565, 429, 150, 147),
#  (576, 412, 121, 83),
#  (587, 279, 87, 102),
#  (615, 502, 100, 74),
#  (619, 523, 52, 49),
#  (698, 0, 481, 444),
#  (698, 0, 481, 448),
#  (698, 0, 559, 448),
#  (698, 162, 174, 202),
#  (702, 0, 477, 444),
#  (802, 190, 277, 261),
#  (840, 190, 239, 261),
#  (902, 0, 377, 249),
#  (951, 0, 328, 167),
#  (994, 0, 237, 167),
#  (994, 0, 285, 167),
#  (1088, 462, 191, 157),
#  (1098, 0, 133, 156),
#  (1148, 148, 131, 101),
#  (1155, 0, 124, 176),
#  (1157, 545, 122, 80),
#  (1161, 0, 118, 176),
# ...

# %%
# draw rectangles on the original image
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.imshow(img)
for x, y, w, h in candidates:
    print x, y, w, h
    rect = mpatches.Rectangle(
        (x, y), w, h, fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)

plt.show()
# Out:
# 0 17 248 222
# 551 0 706 448
# 551 0 728 517
# 393 444 90 108
# 393 444 90 136
# 994 0 237 167
# 551 0 728 576
# 1161 0 118 176
# 1088 462 191 157
# 0 70 1279 649
# 994 0 285 167
# 615 502 100 74
# 1148 148 131 101
# 0 69 1279 650
# 551 65 154 145
# 133 589 115 67
# 404 579 157 95
# 1098 0 133 156
# 802 190 277 261
# 484 0 795 576
# 951 0 328 167
# 1169 0 98 104
# 393 444 90 165
# 698 0 481 448
# 242 475 235 124
# 840 190 239 261
# 619 523 52 49
# 551 0 706 517
# 576 412 121 83
# 1155 0 124 176
# 323 475 154 124
# 698 162 174 202
# 0 547 158 101
# 565 429 150 147
# 1212 109 67 67
# 565 382 150 194
# 0 0 1279 719
# 698 0 481 444
# 551 0 710 517
# 698 0 559 448
# 1157 545 122 80
# 587 279 87 102
# 702 0 477 444
# 902 0 377 249

# %%
img_path = '/home/ubuntu/data/fish/valid/ALB/img_04893.jpg'
img = mpimg.imread(img_path)
plt.imshow(img) #(scipy.misc.imresize(img, (2048,4096), interp='nearest'))
plt.show()

# %%
img_lbl, regions = selectivesearch.selective_search(img, scale=200, sigma=2.5, min_size=1500)
candidates = set()
for r in regions:
    # excluding same rectangle (with different segments)
    if r['rect'] in candidates:
        continue
    # excluding regions smaller than 2000 pixels
    if r['size'] < 2000:
        continue
        # distorted rects
    x, y, w, h = r['rect']
    if w / h > 1.2 or h / w > 1.2:
        continue
    candidates.add(r['rect'])
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.imshow(img)
for x, y, w, h in candidates:
    print x, y, w, h
    rect = mpatches.Rectangle(
        (x, y), w, h, fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)

plt.show()
# Out:
# 0 17 264 206
# 866 612 98 107
# 1038 0 241 214
# 458 142 821 577
# 959 196 78 146
# 911 584 62 104
# 0 540 157 179
# 0 34 1004 685
# 0 17 487 286
# 0 247 107 59
# 936 0 102 88
# 613 629 53 90
# 760 116 77 58
# 559 406 153 94
# 219 141 268 162
# 658 417 138 89
# 160 542 234 177
# 786 671 65 48
# 882 220 55 61
# 599 176 313 219
# 911 584 114 135
# 386 133 59 98
# 158 503 306 216
# 0 57 71 97
# 1053 0 143 77
# 418 387 232 197
# 0 0 1279 719
# 882 0 397 355
# 827 529 182 101
# 599 276 121 97
# 876 208 140 157
# 910 0 369 355
# 602 302 59 62
# 0 34 1004 590
# 661 176 251 219
