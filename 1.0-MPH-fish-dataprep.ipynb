# %%
from IPython.display import display, Image
from keras.preprocessing import image as kimage
import skimage.io
# Out:
# Using TensorFlow backend.

# %%
from glob import glob
import numpy as np
import os, sys

# %%
img_dir = '/home/ubuntu/data/train/ALB'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/BET'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/DOL'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/LAG'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/NoF'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/OTHER'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/SHARK'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
img_dir = '/home/ubuntu/data/train/YFT'
rand_img = np.random.choice(glob.glob(img_dir + '/*.jpg'))
Image(filename=rand_img)

# %%
# %cd /home/ubuntu/data/train
# %mkdir ../valid
# Out:
# /home/ubuntu/data/train

# %%
g = glob('*')
#for d in g: os.mkdir('../valid/'+d)

g = glob('*/*.jpg')
shuf = np.random.permutation(g)
for i in range(500): os.rename(shuf[i], '../valid/' + shuf[i])
